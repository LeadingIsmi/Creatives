# %% [markdown]
# ## Инструкция по использованию скрипта для генерации изображений
#
# ### Описание скрипта
#
# Скрипт позволяет создавать изображения с помощью текстовых описаний (промтов) и различных параметров стилизации.
#
# ### **Основные параметры**
#
# 1. **prompt**: текстовое описание того, что нужно изобразить.
#    - Готовый текстовый промт (описание должно быть на английском языке).
#    - Референсы и примеры промтов можно посмотреть на [Civitai](https://civitai.com/images).
#
# 2. **style**: стиль изображения.
#    - По умолчанию стиль не задан.
#    - Доступные стили:ы
#      - Character
#      - Background
#      - Hyperrealism
#      - Cinematic
#      - Photograph
#      - Masterpiece
#      - Sharp
#      - Comic
#      - Anime
#      - Graffiti
#
# 3. **num_images**: количество генерируемых изображений.
#    - Значение по умолчанию: `1`.
#    - Среднее время генерации одного изображения: 15-30 секунд.
#
# 4. **aspect_ratio**: соотношение сторон изображения.
#    - Значение по умолчанию: `1:1` (разрешение 2048x2048).
#    - Доступные значения: от `21:9` до `9:21`.
#    - Рекомендуемые значения:
#      - Для персонажа в полный рост: `9:16` (разрешение 1536x2752)
#      - Для фона: `16:9` (разрешение 2752x1536)
#
# 5. **seed**: зерно для воспроизводимости сгенерированных изображений.
#    - Значение по умолчанию: `-1` (случайная генерация).
#    - Позволяет получать одинаковые изображения при повторной генерации.
#
# 6. **reference_path**: путь к изображению, которое будет использовано в качестве референса.
#    - По умолчанию параметр не используется (`None`).
#    - Параметр позволяет задать изображение, которое будет служить основой для генерации нового изображения.
#
# 7. **strength**: сила воздействия референсного изображения.
#    - Значение по умолчанию: `1`.
#    - Доступные значения: от `0` до `1`.
#    - Определяет, насколько сильно референсное изображение будет влиять на результат. Чем выше значение, тем сильнее влияние.
#
# 8. **finetune**: возможность генерации образа.
#    - По умолчанию параметр не используется (`None`).
#    - Параметр позволяет применить обученную на образе модель для генерации нового изображения.
#    - Доступные образы:
#      - Elvis frog
#      - Succubus
#      - Rhino
#
# 9. **finetune_strength**: сила воздействия образа.
#    - Значение по умолчанию: `1.2`.
#    - Доступные значения: от `0` до `2`.
#    - Определяет, насколько сильно образ будет влиять на результат. Чем выше значение, тем сильнее влияние.

# %% [markdown]
# # Генерация из промта

# %%
from utils import create_images, show_images

cowgirl_prompt = "A confident cowgirl with wavy blonde hair, wearing a stylish cowboy hat and aviator sunglasses. She is dressed in a fitted leather shirt with rolled-up sleeves and dark green jeans, accessorized with a detailed belt and holster. She holds a deck of playing cards in one hand, exuding a bold and charismatic presence. The background is plain white. The lighting is dramatic, with a warm golden glow highlighting her features. Ultra-detailed, cinematic, high-quality digital painting, realistic textures, Western theme."
indigenous_prompt = "Fantasy art style of a beautiful indigenous woman with long dark hair, wearing a tribal headdress with feathers and intricate beadwork. She is dressed in a detailed, beaded top with tribal patterns, accessorized with multiple bracelets and necklaces. She sits at a table with playing cards spread out, holding a card in one hand and smiling confidently. The background is plain white. The lighting is giving a mystical and elegant feel. Uncropped, centerd, highly detailed, cinematic lighting"
soccer_player_prompt = "A professional soccer player in action, wearing a green and orange uniform. The player has an athletic build, short styled hair, and a friendly expression on his face. He is mid-stride, dribbling a modern football with a star pattern, wearing matching green cleats. The lighting is dramatic, highlighting muscle definition, with a white background. Ultra-realistic, cinematic lighting, 8K resolution, hyper-detailed textures"
basketball_player_prompt = "A basketball player with dark skin, wearing an orange and navy blue sleeveless jersey and shorts, dribbling a basketball while running forward. The player has an athletic build, short styled hair, and a friendly expression on his face. The background is plain white, and the lighting is dramatic."

basketball_arena_prompt = "A modern basketball arena with markings for a basketball court. At night, illuminated by bright stadium spotlights. The polished wooden court reflects the lights, creating a dramatic and cinematic effect. The perspective is from the court, with a blurred audience in the background. Neon LED screens around the stands display dynamic colors. Ultra-realistic, 8K, photorealism, high detail, cinematic lighting."
stadium_prompt = "Epic stadium background, cinematic lighting, ultra-realistic details, packed crowd with blurred faces, bright stadium lights shining down, monotonously green grass field without white lines, dramatic evening sky with deep blue and purple tones, wide panoramic view, high resolution, perfect for banner design"
stadium_prompt2 = "Epic and modern sports stadium background, illuminated by bright floodlights, with a dynamic and energetic atmosphere. The perspective is slightly angled for depth, showcasing the field with a dramatic, cinematic feel. The crowd is blurred to keep the focus on the stadium environment. No players, just the stadium and the field, leaving space for promotional text. High-definition, ultra-detailed, realistic lighting, and a professional sports aesthetic. Perfect for advertising banners"

# %%
images = create_images(
    prompt=basketball_player_prompt,
    style="Comic",
    num_images=1,
    aspect_ratio="9:21",
    output_format="png",
    seed=1652721165
)
show_images(images)
# Out:
# Prompt: A basketball player with dark skin, wearing an orange and navy blue sleeveless jersey and shorts, dribbling a basketball while running forward. The player has an athletic build, short styled hair, and a friendly expression on his face. The background is plain white, and the lighting is dramatic.
# Full prompt: comic A basketball player with dark skin, wearing an orange and navy blue sleeveless jersey and shorts, dribbling a basketball while running forward. The player has an athletic build, short styled hair, and a friendly expression on his face. The background is plain white, and the lighting is dramatic., graphic illustration, comic art, graphic novel art, vibrant, highly detailed, visually appealing, attractive
#
# Генерация изображения 1:
# Статус: Pending - 0.5
# Статус: Pending - 0.6
# Статус: Pending - 0.6
# Статус: Pending - 1.0
# Статус: Ready - None
# Изображение успешно сохранено: outputs\2025-04-09\2025-04-09_03-09-06_3913.png

# %% [markdown]
# # Генерация из изображения

# %%
from utils import create_images, show_images

styles = create_images(
    #prompt=prompt,
    reference_path=r"outputs\2025-03-04\2025-03-04_16-11-26_4581.png",
    strength=0.8,
    num_images=2,
    aspect_ratio="9:16",
    seed=123
)
show_images(styles)
# Out:
# Prompt:
# Full prompt:
#
# Генерация изображения 1:
# Статус: Pending - 0.3
# Статус: Pending - 0.4
# Статус: Pending - 0.5
# Статус: Pending - 1.0
# Статус: Ready - None
# Изображение успешно сохранено: outputs\2025-03-04\2025-03-04_16-24-07_1105.png
#
# Генерация изображения 2:
# Статус: Pending - 0.3
# Статус: Pending - 0.4
# Статус: Pending - 0.5
# Статус: Pending - 1.0
# Статус: Ready - None
# Изображение успешно сохранено: outputs\2025-03-04\2025-03-04_16-24-24_1682.png

# %% [markdown]
# # Генерация из образа

# %%
from utils import create_images, show_images

rhino_finetune = "rhino"
succub_finetune = "succub"
frog_finetune = "elvis_frog"
researcher_finetune = "researcher"

rhino_prompt = "comic bald rhino, cocktail in hand, hat on head, wearing a Hawaiian shirt"
rhino_prompt2 = "comic rhino, holding a neatly stack of bills in his hand, wearing a T-shirt with the inscription 'BIZZO'"
rhino_prompt3 = "comic rhino, holding a little mountain of gold coins with both hands, wearing a T-shirt with the inscription 'BIZZO'"
rhino_prompt4 = "comic woman rhino, blonde, scarlet eyes, holding a bouquet of scarlet roses in hands, wearing a black dress"

succub_prompt = "succubus, standing, wearing green blazer, stretch out a big winner's golden cup with the inscription 'HELLSPIN' in her hands into the viever, enhanced, 4k, high-res, masterpiece, best quality, finely detailed face and hair, sharp focus, cinematic lighting"

frog_prompt = "frog, jumping into the viever"
frog_prompt2 = "frog, showing 'WOOCASINO' sign"
frog_prompt3 = "frog, with a cup of tea in hand"
frog_prompt4 = "frog, throws out paper bills like they're confetti"
frog_prompt5 = "frog, with a mohawk, playing electric guitar"
frog_prompt6 = "frog, with black glasses, black leather jacket and pants, rides a motorbike"

researcher_prompt = 'man, researcher, standing in full gear'
researcher_prompt2 = 'man, researcher, standing, attacks with his fists'
researcher_prompt3 = 'man, researcher, jumping into the viever'
researcher_prompt4 = 'man, researcher, rides a horse, aims a pistol'
researcher_prompt5 = 'man, researcher, standing, smiling, holding a golden glowing jewel in his hands'
researcher_prompt6 = 'man, researcher, standing, interested, reading a mysterious glowing book with an emerald on the cover'
researcher_prompt7 = 'man, researcher, standing, happy, is in a large tomb with gold coins, jewelry and chests of gold'

# %%
from utils import create_images, show_images

rhino_finetune = "rhino"
succub_finetune = "succub"
frog_finetune = "elvis_frog"
researcher_finetune = "researcher"

frog_prompt = "frog, wearing a green St. Patrick’s Day hat, in a green leather jacket and jeans, singing into a microphone, standing on a plain white background, surrounded by floating clover leaves and scattered golden coins, St. Patrick’s Day theme"
frog_prompt2 = "frog, wearing a green St. Patrick’s Day hat, playing poker at a casino table, with a stack of golden chips, simple white background with light green accents, clover decorations on the table"
frog_prompt3 = "rock-n-roll frog, wearing a green St. Patrick’s Day hat, in a green leather jacket and jeans, holding a golden microphone, standing on a solid white background, with clovers and golden coins floating around, casino roulette wheel in the distance"
frog_prompt4 = "frog, wearing a green St. Patrick's Day hat, posing around a slot machine with three green clover symbols on the reels, plain white background, a St. Patrick’s Day atmosphere"

rhino_prompt = "comic rhino, wearing a green St. Patrick’s Day hat, in green outfit, holding dice in his hands, on a white background with scattered gold coins and poker chips, simple clover designs in the background"
rhino_prompt2 = "comic rhino, wearing a green St. Patrick’s Day hat, in clover-patterned suit, sitting at a slot machine, with green lights flashing, white background, St. Patrick’s Day theme with subtle green clover elements"
rhino_prompt3 = "comic rhino, wearing a green St. Patrick’s Day hat, with oversized glasses and green bowtie, playing poker at a table with golden chips, clovers scattered across the clean white background, festive casino lights"
rhino_prompt4 = "comic rhino, wearing a green St. Patrick’s Day hat, standing proudly with a jackpot of gold coins, in front of a solid white background, clovers subtly floating around him, casino decorations"

succub_prompt = "comic succubus, wearing a green St. Patrick’s Day hat, wearing a green sparkling corset, standing on a plain white background, holding a glowing casino card, with subtle clover-shaped patterns floating in the air around her"
succub_prompt2 = "comic succubus, wearing a green St. Patrick’s Day hat, with glowing green eyes, in a flowing emerald gown, sitting in a velvet casino chair on a white background, golden coins spilling from her hands, St. Patrick’s Day theme"
succub_prompt3 = "comic succubus, wearing a green St. Patrick’s Day hat, tight green leather outfit, stretch out a big winner's golden cup in her hands into the viever, mystical green smoke around her, on a plain white background"
succub_prompt4 = "comic succubus, in green outfit, perched on a throne of golden coins, wearing a shamrock crown, standing in front of a plain white background, holding a blackjack card, St. Patrick’s Day festive feel"

researcher_prompt = "man, researcher, in St. Patrick’s Day hat, in a green leather jacket and adventurer gear, standing on a white background, surrounded by scattered golden coins, playing cards, and clovers, St. Patrick’s Day theme"
researcher_prompt2 = "man, researcher, in St. Patrick’s Day hat, in green outfit, uncovering treasures in an ancient tomb, with a clean white background, golden coins and shamrock decorations around him, St. Patrick’s Day celebration"
researcher_prompt3 = "man, researcher, in St. Patrick’s Day hat, wearing green tactical gear, swinging from a vine, standing against a white background, surrounded by golden coins and clovers, holding a lucky casino card"
researcher_prompt4 = "man, researcher, in St. Patrick’s Day hat, in a clover-patterned bandana, searching for treasure in a white background, surrounded by golden coins and St. Patrick’s Day symbols"

# %%
from utils import create_images, show_images

rhino_finetune = "rhino"
frog_finetune = "elvis_frog"
succub_finetune = "succub"
researcher_finetune = "researcher"

rhino_prompt = "comic rhino, wearing Easter costume, holding a large basket of eggs in one hand, holding a betting ticket with the inscription 'BIZZO' in the other hand, white background."
rhino_prompt2 = "comic rhino, wearing Easter costume, holding a bright Easter egg in hand, standing next to a casino roulette wheel, focus on excitement and victory, white background."
rhino_prompt3 = "comic rhino, wearing Easter costume, wearing glasses, holding a cocktail, standing in front of Easter decorations with eggs, white background."
rhino_prompt4 = "comic rhino, wearing Easter bunny hat, cheerfully pointing at a screen with the inscription 'BIZZO', white background."
rhino_prompt5 = "comic rhino, wearing Easter costume, surrounded by Easter eggs, white background."
rhino_prompt6 = "comic rhino, in Easter gear, holding a large golden Easter egg, jackpot atmosphere, white background."

frog_prompt = "singing frog, wearing Easter costume, holding a microphone, performing on a casino stage, white background."
frog_prompt2 = "singing frog, in Easter attire, with garlands and golden eggs, white background."
frog_prompt3 = "frog, with headphones and a microphone, wearing an Easter hat, ready for winning bets, white background."
frog_prompt4 = "frog, in glamorous Easter outfit, sitting on a roulette wheel with a microphone, ready to announce winners, white background."
frog_prompt5 = "frog, wearing Easter costume, posing around a slot machine, white background."
frog_prompt6 = "frog, in a bright costume with Easter eggs, holding a betting card with predictions for sports events, white background."

succub_prompt = "comic succubus, wearing pink Easter dress and bunny hat, with a mysterious look, Easter holiday atmosphere, white background."
succub_prompt2 = "comic succubus, wearing Easter costume and bunny hat, holding a phone screen with the inscription 'HELLSPIN', white background."
succub_prompt3 = "comic succubus, wearing pink Easter dress, bunny hat, posing with Easter egg, white background."
succub_prompt4 = "comic succubus, wearing pink Easter dress, bunny hat, with sparkling golden eggs and Easter accessories, white background."
succub_prompt5 = "comic succubus, wearing pink Easter dress, bunny hat, in pastel Easter colors, holding a basket of eggs, white background."

researcher_prompt = "Man, explorer, holding a map with Easter eggs scattered around him, surrounded by pastel Easter decorations, white background."
researcher_prompt2 = "Man, explorer, standing, carrying a bag filled with colorful Easter eggs, smiling in front of a festive Easter scene, white background."
researcher_prompt3 = "Man, explorer, in a stylish outfit and a satchel, standing next to a pile of Easter eggs and spring flowers, ready for an Easter egg hunt, white background."
researcher_prompt4 = "Man, explorer, standing, holding a large golden Easter egg, surrounded by blooming flowers, white background."
researcher_prompt5 = "Man, explorer, wearing an Easter-themed scarf and hat, standing in front of a scenic Easter picnic, white background."
researcher_prompt6 = "Man, explorer, standing, holding a lantern and a basket filled with Easter eggs, surrounded by festive decorations, white background."

# %%
loras = create_images(
    prompt=researcher_prompt6,
    finetune=researcher_finetune,  
    finetune_strength=1.2,
    num_images=1,
    aspect_ratio="9:16",
    seed=463438974,
) 
show_images(loras)
# Out:
# Prompt: Man, explorer, standing, holding a lantern and a basket filled with Easter eggs, surrounded by festive decorations, white background.
# Full prompt: Man, explorer, standing, holding a lantern and a basket filled with Easter eggs, surrounded by festive decorations, white background.
#
# Генерация изображения 1:
# Статус: Pending - None
# Статус: Pending - None
# Статус: Pending - 0.4
# Статус: Pending - 0.4
# Статус: Pending - 0.4
# Статус: Pending - 0.4
# Статус: Pending - 0.5
# Статус: Ready - None
# Изображение успешно сохранено: outputs\2025-03-04\2025-03-04_14-48-18_7643.png

# %% [markdown]
# # Апсйкел изображения

# %%
from utils import upscale_images, show_images

paths = [r"outputs\2025-03-08\2025-03-08_14-59-44_4211.png"]

upscaled_images = upscale_images(paths, outscale=2)
show_images(upscaled_images)

# %% [markdown]
# # Обрезка изобржаения

# %%
from utils import extract_images, show_images

paths = [r"outputs\2025-03-08\2025-03-08_14-59-44_4211.png", ]

extracted_images = extract_images(paths)
show_images(extracted_images)
# Out:
# Изображение успешно сохранено: outputs\extract\2025-03-08_16-46-36_8169.png
